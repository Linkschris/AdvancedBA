# %%
# exercise 10_1_5
import importlib_resources
import numpy as np
from matplotlib import pyplot as plt
from scipy.io import loadmat
from sklearn.cluster import k_means
import pandas as pd

# %%
data = pd.read_csv('data.csv')
prices = data[['date','price_GER']]

# %%
# create a df with one column for each hour and one row for each day
prices_copy = prices.copy()
prices_copy['hour'] = prices_copy['date'].str.extract('(\d+):').astype(int)
prices_copy['day'] = prices_copy['date'].str.extract('(\d+-\d+-\d+)')
prices_tab = prices_copy.pivot(index='day', columns='hour', values='price_GER')
prices_tab
# Out:
# hour             0        1        2        3        4        5        6   \
# day
# 2019-01-01  28.3200  10.0700  -4.0800  -9.9100  -7.4100 -12.5500 -17.2500
# 2019-01-02 -33.5700 -45.9200 -48.2900 -44.9900 -48.9300 -29.9100  -0.0100
# 2019-01-03  42.9100  45.2200  45.6300  44.0000  43.8800  45.9200  51.0700
# 2019-01-04  50.7300  47.1100  47.0700  46.9400  47.0000  46.9100  49.5900
# 2019-01-05  26.9000  25.1200  24.1200  22.0400  18.3700  22.0900  23.3500
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-27  33.0725  33.0675  31.7550  31.5875  30.4300  43.7900  59.9100
# 2023-12-28   1.8875   0.3825   0.2825  -0.9175  -0.7425   0.6700   4.3225
# 2023-12-29  -5.0475  -7.5475  -7.2400  -8.3450  -8.4475  -7.2175  -6.5350
# 2023-12-30  12.4350   7.4400   1.9125   0.1100  -0.0975   2.6900   4.9875
# 2023-12-31  28.7625      NaN      NaN      NaN      NaN      NaN      NaN
#
# hour             7        8        9   ...       14       15       16  \
# day                                    ...
# 2019-01-01 -15.0700  -4.9300  -6.3300  ...   0.0000  -0.0300   1.9700
# 2019-01-02  37.4300  48.0600  50.7400  ...  49.6400  53.6700  56.0100
# 2019-01-03  52.7700  62.8900  60.0300  ...  65.2400  67.7600  68.4100
# 2019-01-04  55.3200  55.7800  55.5200  ...  51.4100  51.6900  52.5900
# 2019-01-05  28.7600  36.6300  40.4600  ...  51.9200  53.2200  56.6200
# ...             ...      ...      ...  ...      ...      ...      ...
# 2023-12-27  89.0025  88.7175  88.9775  ...  62.7150  62.7925  75.0175
# 2023-12-28  25.7675  33.8075  36.7600  ...  32.0800  41.7325  45.7100
# 2023-12-29   1.4950   9.1875  10.0025  ...   1.5450   9.8575  17.3125
# 2023-12-30  16.2650  29.8275  30.2850  ...  29.1025  47.1675  61.9975
# 2023-12-31      NaN      NaN      NaN  ...      NaN      NaN      NaN
#
# hour             17       18       19       20       21       22       23
# day
# 2019-01-01   9.0600   0.0700  -4.9700  -6.9800 -24.9300  -4.8700 -28.9300
# 2019-01-02  56.9500  62.0800  62.1100  57.9900  55.6400  55.1300  50.7600
# 2019-01-03  69.5500  67.2800  69.4600  68.3800  61.7200  53.7200  49.9800
# 2019-01-04  54.6600  54.1000  51.8900  46.5800  45.4300  43.9600  31.4100
# 2019-01-05  56.9200  61.6400  59.4400  52.7500  51.9000  51.3800  49.9600
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-27  87.6775  86.2675  70.7775  61.2700  56.3100  50.4100  37.0400
# 2023-12-28  64.0825  59.4825  52.2175  29.9075  20.5400  16.8000   3.2225
# 2023-12-29  33.2650  34.4875  26.9725  18.2500  12.3675  11.0025   5.8400
# 2023-12-30  74.0050  75.3225  68.6350  63.2200  58.7550  51.7450  43.4600
# 2023-12-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [1795 rows x 24 columns]

# %%
# drop the rows with missing values
prices_tab = prices_tab.dropna()
prices_tab
# Out:
# hour             0        1        2        3        4        5        6   \
# day
# 2019-01-01  28.3200  10.0700  -4.0800  -9.9100  -7.4100 -12.5500 -17.2500
# 2019-01-02 -33.5700 -45.9200 -48.2900 -44.9900 -48.9300 -29.9100  -0.0100
# 2019-01-03  42.9100  45.2200  45.6300  44.0000  43.8800  45.9200  51.0700
# 2019-01-04  50.7300  47.1100  47.0700  46.9400  47.0000  46.9100  49.5900
# 2019-01-05  26.9000  25.1200  24.1200  22.0400  18.3700  22.0900  23.3500
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-26   5.2150   0.2050  -4.6000  -4.5000  -3.0150  -4.5300  -2.6725
# 2023-12-27  33.0725  33.0675  31.7550  31.5875  30.4300  43.7900  59.9100
# 2023-12-28   1.8875   0.3825   0.2825  -0.9175  -0.7425   0.6700   4.3225
# 2023-12-29  -5.0475  -7.5475  -7.2400  -8.3450  -8.4475  -7.2175  -6.5350
# 2023-12-30  12.4350   7.4400   1.9125   0.1100  -0.0975   2.6900   4.9875
#
# hour             7        8        9   ...       14       15       16  \
# day                                    ...
# 2019-01-01 -15.0700  -4.9300  -6.3300  ...   0.0000  -0.0300   1.9700
# 2019-01-02  37.4300  48.0600  50.7400  ...  49.6400  53.6700  56.0100
# 2019-01-03  52.7700  62.8900  60.0300  ...  65.2400  67.7600  68.4100
# 2019-01-04  55.3200  55.7800  55.5200  ...  51.4100  51.6900  52.5900
# 2019-01-05  28.7600  36.6300  40.4600  ...  51.9200  53.2200  56.6200
# ...             ...      ...      ...  ...      ...      ...      ...
# 2023-12-26   6.9400   3.7850   3.3200  ...   0.6875   8.1875  44.4850
# 2023-12-27  89.0025  88.7175  88.9775  ...  62.7150  62.7925  75.0175
# 2023-12-28  25.7675  33.8075  36.7600  ...  32.0800  41.7325  45.7100
# 2023-12-29   1.4950   9.1875  10.0025  ...   1.5450   9.8575  17.3125
# 2023-12-30  16.2650  29.8275  30.2850  ...  29.1025  47.1675  61.9975
#
# hour             17       18       19       20       21       22       23
# day
# 2019-01-01   9.0600   0.0700  -4.9700  -6.9800 -24.9300  -4.8700 -28.9300
# 2019-01-02  56.9500  62.0800  62.1100  57.9900  55.6400  55.1300  50.7600
# 2019-01-03  69.5500  67.2800  69.4600  68.3800  61.7200  53.7200  49.9800
# 2019-01-04  54.6600  54.1000  51.8900  46.5800  45.4300  43.9600  31.4100
# 2019-01-05  56.9200  61.6400  59.4400  52.7500  51.9000  51.3800  49.9600
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-12-26  51.5450  51.8625  51.7900  51.9425  51.7425  51.7025  49.2800
# 2023-12-27  87.6775  86.2675  70.7775  61.2700  56.3100  50.4100  37.0400
# 2023-12-28  64.0825  59.4825  52.2175  29.9075  20.5400  16.8000   3.2225
# 2023-12-29  33.2650  34.4875  26.9725  18.2500  12.3675  11.0025   5.8400
# 2023-12-30  74.0050  75.3225  68.6350  63.2200  58.7550  51.7450  43.4600
#
# [1781 rows x 24 columns]

# %%
# Make sure that each rows has a mean of 0 and a standard deviation of 1
prices_tab = prices_tab.apply(lambda x: (x - x.mean()) / x.std(), axis=1)
prices_tab
# Out:
# hour              0         1         2         3         4         5   \
# day
# 2019-01-01  2.835846  1.249126  0.018874 -0.488007 -0.270648 -0.717538
# 2019-01-02 -1.418533 -1.713030 -1.769545 -1.690853 -1.784806 -1.331257
# 2019-01-03 -1.550323 -1.308449 -1.265519 -1.436192 -1.448757 -1.235154
# 2019-01-04  0.154060 -0.526058 -0.533573 -0.557997 -0.546724 -0.563633
# 2019-01-05 -1.067491 -1.191839 -1.261697 -1.407002 -1.663381 -1.403509
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-26 -0.480957 -0.685443 -0.881562 -0.877480 -0.816869 -0.878705
# 2023-12-27 -1.330084 -1.330324 -1.393328 -1.401369 -1.456932 -0.815609
# 2023-12-28 -1.115823 -1.191237 -1.196248 -1.256379 -1.247610 -1.176831
# 2023-12-29 -0.911055 -1.108258 -1.084002 -1.171166 -1.179252 -1.082228
# 2023-12-30 -0.721806 -0.916390 -1.131718 -1.201936 -1.210020 -1.101430
#
# hour              6         7         8         9   ...        14        15  \
# day                                                 ...
# 2019-01-01 -1.126173 -0.936636 -0.055028 -0.176749  ...  0.373604  0.370995
# 2019-01-02 -0.618265  0.274526  0.528008  0.591915  ...  0.565684  0.661783
# 2019-01-03 -0.695911 -0.517909  0.541730  0.242267  ...  0.787792  1.051654
# 2019-01-04 -0.060121  1.016418  1.102842  1.053994  ...  0.281817  0.334422
# 2019-01-05 -1.315488 -0.937555 -0.387771 -0.120214  ...  0.680360  0.771176
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-12-26 -0.802890 -0.410550 -0.539323 -0.558302  ... -0.665749 -0.359632
# 2023-12-27 -0.041798  1.354735  1.341055  1.353535  ...  0.092851  0.096571
# 2023-12-28 -0.993808  0.080780  0.483656  0.631603  ...  0.397093  0.880770
# 2023-12-29 -1.028391 -0.394974  0.211821  0.276109  ... -0.391030  0.264672
# 2023-12-30 -1.011929 -0.572605 -0.044268 -0.026445  ... -0.072511  0.631226
#
# hour              16        17        18        19        20        21  \
# day
# 2019-01-01  0.544883  1.161313  0.379690 -0.058506 -0.233262 -1.793900
# 2019-01-02  0.717583  0.739998  0.862328  0.863043  0.764798  0.708760
# 2019-01-03  1.119714  1.239081  1.001395  1.229657  1.116573  0.419222
# 2019-01-04  0.503512  0.892419  0.787208  0.371998 -0.625633 -0.841692
# 2019-01-05  1.008694  1.029651  1.359382  1.205694  0.738343  0.678963
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-26  1.121872  1.410030  1.422989  1.420030  1.426255  1.418092
# 2023-12-27  0.683411  1.291131  1.223447  0.479877  0.023487 -0.214609
# 2023-12-28  1.080079  2.000707  1.770205  1.406163  0.288231 -0.181165
# 2023-12-29  0.852732  2.111087  2.207519  1.614726  0.926683  0.462664
# 2023-12-30  1.208940  1.676702  1.728026  1.467509  1.256564  1.082626
#
# hour              22        23
# day
# 2019-01-01 -0.049811 -2.141674
# 2019-01-02  0.696598  0.592392
# 2019-01-03 -0.418437 -0.810042
# 2019-01-04 -1.117872 -3.475738
# 2019-01-05  0.642637  0.543438
# ...              ...       ...
# 2023-12-26  1.416459  1.317583
# 2023-12-27 -0.497828 -1.139631
# 2023-12-28 -0.368573 -1.048928
# 2023-12-29  0.354991 -0.052234
# 2023-12-30  0.809546  0.486797
#
# [1781 rows x 24 columns]

# %%
# plot the data for 10 random rows
plt.figure()
prices_tab.sample(10).T.plot(legend=False)
plt.show()

# %%
# do a PCA on the data
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(prices_tab)
plt.figure()
plt.plot(pca.explained_variance_ratio_)
plt.show()

# Print the explained variance of the first 3 components
print(pca.explained_variance_ratio_[:3])
# Out:
# [0.47628318 0.20383066 0.12329441]

# %%
# do subplots with PC1 vs PC2, PC2 vs PC3 and PC1 vs PC3, and change the widht of the plot
pca = PCA(n_components=3)
X = pca.fit_transform(prices_tab)
plt.figure()
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.scatter(X[:,0], X[:,1])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.subplot(132)
plt.scatter(X[:,1], X[:,2])
plt.xlabel('PC2')
plt.ylabel('PC3')
plt.subplot(133)
plt.scatter(X[:,0], X[:,2])
plt.xlabel('PC1')
plt.ylabel('PC3')
plt.show()

# %%
# Do only a PCA on the data with 2 PCs
pca = PCA(n_components=2)
X = pca.fit_transform(prices_tab)
plt.figure()
plt.scatter(X[:,0], X[:,1])
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
# Most of the explained variance is in the first and second component, so we can do a clustering only using PC1 and PC2
# Let's do a k-means clustering with a given number of cluster
from sklearn.cluster import KMeans

# Number of clusters:
K = 8

# Number of repetitions with different initial centroid seeds
S = 5

# Run k-means clustering:
centroids, cls, inertia = k_means(X, K, verbose=True, max_iter=100, n_init=S)

# Plot results:

# Plot centroids
plt.figure(1)
plt.figure(figsize=(15,5))
n1 = int(np.ceil(np.sqrt(K/2)))
n2 = int(np.ceil(float(K)/n1))
for k in range(K):
    plt.subplot(n1,n2,k+1)
    plt.plot(centroids[k,0], centroids[k,1], 'r*', markersize=10)
    plt.scatter(X[cls==k,0], X[cls==k,1])
    plt.title('Cluster %d' % k)
plt.show()
# Out:
# Initialization complete
# Iteration 0, inertia 2471.220083599337.
# Iteration 1, inertia 2143.140360183664.
# Iteration 2, inertia 2092.5073724731483.
# Iteration 3, inertia 2083.6816212164094.
# Iteration 4, inertia 2079.9953262806134.
# Iteration 5, inertia 2077.28692229424.
# Iteration 6, inertia 2075.976165907495.
# Iteration 7, inertia 2073.10203472044.
# Iteration 8, inertia 2069.422949475653.
# Iteration 9, inertia 2067.7099329455064.
# Iteration 10, inertia 2066.436646079071.
# Iteration 11, inertia 2065.262860140897.
# Iteration 12, inertia 2063.821884245728.
# Iteration 13, inertia 2062.943354771205.
# Iteration 14, inertia 2062.079672961214.
# Converged at iteration 14: center shift 0.00019611267893156206 within tolerance 0.0004189494101821455.
# Initialization complete
# Iteration 0, inertia 2613.848760979769.
# Iteration 1, inertia 2269.5248890734483.
# Iteration 2, inertia 2153.5461798556744.
# Iteration 3, inertia 2119.34411657884.
# Iteration 4, inertia 2104.8420020351487.
# Iteration 5, inertia 2095.875468120248.
# Iteration 6, inertia 2091.560501780499.
# Iteration 7, inertia 2090.53645470032.
# Iteration 8, inertia 2089.880503917929.
# Iteration 9, inertia 2089.052493750899.
# Iteration 10, inertia 2087.2610970040296.
# Iteration 11, inertia 2086.4958707945884.
# Iteration 12, inertia 2085.7503707024407.
# Iteration 13, inertia 2084.476752626794.
# Iteration 14, inertia 2083.954075479973.
# Iteration 15, inertia 2082.9331584867537.
# Iteration 16, inertia 2081.9319934873374.
# Iteration 17, inertia 2081.14818189613.
# Iteration 18, inertia 2079.7808188599693.
# Iteration 19, inertia 2076.3535713310175.
# Iteration 20, inertia 2069.3220641991556.
# Iteration 21, inertia 2064.38909512217.
# Iteration 22, inertia 2058.6157113041418.
# Iteration 23, inertia 2053.0073540320655.
# Iteration 24, inertia 2048.408365339258.
# Iteration 25, inertia 2035.890204997681.
# Iteration 26, inertia 2020.3567985191362.
# Iteration 27, inertia 2010.5335982228946.
# Iteration 28, inertia 2006.603208094639.
# Iteration 29, inertia 2005.235104903592.
# Iteration 30, inertia 2004.6379648336638.
# Iteration 31, inertia 2003.9507354627667.
# Iteration 32, inertia 2003.4262109086726.
# Iteration 33, inertia 2002.8090487365153.
# Iteration 34, inertia 2002.4679575695714.
# Iteration 35, inertia 2002.28875294014.
# Converged at iteration 35: center shift 0.0001856822608165849 within tolerance 0.0004189494101821455.
# Initialization complete
# Iteration 0, inertia 2408.4740643131468.
# Iteration 1, inertia 2229.545129509844.
# Iteration 2, inertia 2172.44392452428.
# Iteration 3, inertia 2138.679689373531.
# Iteration 4, inertia 2106.3373781978903.
# Iteration 5, inertia 2077.4688728368174.
# Iteration 6, inertia 2063.653288225223.
# Iteration 7, inertia 2055.1322511769563.
# Iteration 8, inertia 2050.2807364791565.
# Iteration 9, inertia 2047.732223822391.
# Iteration 10, inertia 2045.6968567170215.
# Iteration 11, inertia 2044.4746795750266.
# Iteration 12, inertia 2042.892096302488.
# Iteration 13, inertia 2040.942359417062.
# Iteration 14, inertia 2037.8447971340465.
# Iteration 15, inertia 2034.5457547137285.
# Iteration 16, inertia 2032.31384497332.
# Iteration 17, inertia 2031.1649964590804.
# Iteration 18, inertia 2030.0405246292676.
# Iteration 19, inertia 2028.9516697818726.
# Iteration 20, inertia 2027.9031408912383.
# Iteration 21, inertia 2027.5087849111487.
# Iteration 22, inertia 2026.7767302090933.
# Iteration 23, inertia 2025.63768345282.
# Iteration 24, inertia 2025.0564983957834.
# Iteration 25, inertia 2024.753679435787.
# Converged at iteration 25: center shift 0.00025307186192470013 within tolerance 0.0004189494101821455.
# Initialization complete
# Iteration 0, inertia 2420.555965077261.
# Iteration 1, inertia 2160.598863304531.
# Iteration 2, inertia 2134.1399259897985.
# Iteration 3, inertia 2117.062720619576.
# Iteration 4, inertia 2104.957431131732.
# Iteration 5, inertia 2097.9038989260525.
# Iteration 6, inertia 2093.3322798471036.
# Iteration 7, inertia 2091.042246252102.
# Iteration 8, inertia 2089.0392445855127.
# Iteration 9, inertia 2087.1798786500726.
# Iteration 10, inertia 2085.7900107235528.
# Iteration 11, inertia 2083.424937057608.
# Iteration 12, inertia 2079.818210017138.
# Iteration 13, inertia 2075.1510385081856.
# Iteration 14, inertia 2070.0808087106175.
# Iteration 15, inertia 2064.693535864926.
# Iteration 16, inertia 2060.447036439409.
# Iteration 17, inertia 2056.0343273690937.
# Iteration 18, inertia 2053.752876136364.
# Iteration 19, inertia 2051.6362459217567.
# Iteration 20, inertia 2049.656167554054.
# Iteration 21, inertia 2045.7935515376694.
# Iteration 22, inertia 2041.8228859903215.
# Iteration 23, inertia 2039.9767415237163.
# Iteration 24, inertia 2038.8476587430205.
# Iteration 25, inertia 2037.8729606712277.
# Iteration 26, inertia 2036.353364289659.
# Iteration 27, inertia 2035.2221632489586.
# Iteration 28, inertia 2034.8730337080947.
# Iteration 29, inertia 2034.1646909858082.
# Iteration 30, inertia 2033.3963633360947.
# Iteration 31, inertia 2032.6658891024874.
# Iteration 32, inertia 2031.0825102983144.
# Iteration 33, inertia 2029.767592404806.
# Iteration 34, inertia 2029.3087959727104.
# Iteration 35, inertia 2028.926350676089.
# Iteration 36, inertia 2028.4892258305263.
# Iteration 37, inertia 2027.6336031335754.
# Iteration 38, inertia 2027.1743847597404.
# Iteration 39, inertia 2026.7832209447035.
# Iteration 40, inertia 2026.2156984816552.
# Iteration 41, inertia 2025.785706707913.
# Converged at iteration 41: center shift 0.0002900045306465779 within tolerance 0.0004189494101821455.
# Initialization complete
# Iteration 0, inertia 2483.738850117019.
# Iteration 1, inertia 2147.9885507846802.
# Iteration 2, inertia 2082.5501542315833.
# Iteration 3, inertia 2069.099770946283.
# Iteration 4, inertia 2060.8234412947168.
# Iteration 5, inertia 2053.958675874072.
# Iteration 6, inertia 2046.563398282246.
# Iteration 7, inertia 2038.8134042911709.
# Iteration 8, inertia 2032.9764166609941.
# Iteration 9, inertia 2028.5530134285318.
# Iteration 10, inertia 2024.8761660837445.
# Iteration 11, inertia 2021.976748157751.
# Iteration 12, inertia 2019.15646356612.
# Iteration 13, inertia 2016.771281711953.
# Iteration 14, inertia 2014.8489804059195.
# Iteration 15, inertia 2012.2146557825236.
# Iteration 16, inertia 2008.3183999273645.
# Iteration 17, inertia 2002.0321012101413.
# Iteration 18, inertia 1997.7960731948453.
# Iteration 19, inertia 1996.7898133022188.
# Iteration 20, inertia 1996.3594257936552.
# Iteration 21, inertia 1996.1594925542408.
# Iteration 22, inertia 1996.025742091952.
# Converged at iteration 22: center shift 0.00012661315356867712 within tolerance 0.0004189494101821455.

# %%
# Let's plot the data with the cluster color
plt.figure()
plt.scatter(X[:,0], X[:,1], c=cls)
plt.show()

# %%
# Let's plot the centroids in the original space of the data
centroids = pca.inverse_transform(centroids)
plt.figure()
plt.plot(centroids.T)
plt.show()

# %%
# create a CSV file with the centroids in the original space, with hours as rows and clusters as columns
df = pd.DataFrame(centroids.T, columns=['Cluster %d' % k for k in range(K)])
df.to_csv('plans.csv', index=False)
